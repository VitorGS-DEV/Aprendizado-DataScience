# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %matplotlib notebook

df = pd.read_csv(r'C:\Users\vitor\Documents\Anaconda\a07e6129f8\sinasc_RO_2019.csv')
df.shape
# Out:
# (27028, 69)

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
sns.boxplot(y="IDADEMAE", data=df)
# Out:
# <Axes: ylabel='IDADEMAE'>

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sns.boxplot(y="PESO", data=df)
# Out:
# <Axes: ylabel='PESO'>

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
sns.histplot(df['IDADEMAE'], bins=21, kde= True, color='yellow')
#kde -  estimativa de densidade
# Out:
# <Axes: xlabel='IDADEMAE', ylabel='Count'>

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
sns.histplot(df['PESO'], bins=30, kde= False, color='green')
# Out:
# <Axes: xlabel='PESO', ylabel='Count'>
